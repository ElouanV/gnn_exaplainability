# %%
from pattern_mining import *

# %%
number_of_graph_per_rule = utils.MUTAGENICITY_NUMBER_OF_GRAPH_PER_RULE

# %%
gs = gspan_mine_rule(rule=1, with_neighbors=True, supp_ratio=0.9)
# Out:
# Number of graphs: 2923
# 100%|██████████| 2923/2923 [00:04<00:00, 707.05it/s]
# Skipped 14 graphs
# t # 0
# v 0 0
# v 1 4
# e 0 1 0
#
# Support: 2811
# -----------------
#
# Read:	0.13 s
# Mine:	0.27999999999999997 s
# Total:	0.41 s

# %% [markdown]
# For some rule, we need to reduce the support ratio

# %%
gspan_mine_rule(rule=9, with_neighbors=True, supp_ratio=0.5)
# Out:
# Number of graphs: 5915
# 100%|██████████| 5915/5915 [00:08<00:00, 670.41it/s]
# Skipped 0 graphs
# t # 0
# v 0 1
# v 1 4
# e 0 1 0
#
# Support: 3005
# -----------------
#
# Read:	0.21 s
# Mine:	0.19999999999999998 s
# Total:	0.41 s

# %%
gspan_mine_rule(rule=12, with_neighbors=True, supp_ratio=0.9)
# Out:
# Number of graphs: 1440
# 100%|██████████| 1440/1440 [00:02<00:00, 680.39it/s]
# Skipped 14 graphs
# t # 0
# v 0 0
# v 1 0
# e 0 1 0
#
# Support: 1404
# -----------------
#
# t # 1
# v 0 0
# v 1 0
# v 2 0
# e 0 1 0
# e 1 2 0
#
# Support: 1402
# -----------------
#
# Read:	0.02 s
# Mine:	0.53 s
# Total:	0.55 s

# %%
gspan_mine_rule(rule=23, with_neighbors=True, supp_ratio=0.9)
# Out:
# Number of graphs: 4278
# 100%|██████████| 4278/4278 [00:06<00:00, 621.43it/s]
# Skipped 0 graphs
# t # 0
# v 0 0
# v 1 0
# e 0 1 0
#
# Support: 4264
# -----------------
#
# t # 1
# v 0 0
# v 1 0
# v 2 0
# e 0 1 0
# e 1 2 0
#
# Support: 4244
# -----------------
#
# t # 2
# v 0 0
# v 1 0
# v 2 0
# v 3 3
# e 0 1 0
# e 1 2 0
# e 1 3 0
#
# Support: 4195
# -----------------
#
# t # 3
# v 0 0
# v 1 0
# v 2 0
# v 3 0
# e 0 1 0
# e 1 2 0
# e 2 3 0
#
# Support: 3952
# -----------------
#
# t # 4
# v 0 0
# v 1 0
# v 2 0
# v 3 0
# v 4 3
# e 0 1 0
# e 1 2 0
# e 2 3 0
# e 2 4 0
#
# Support: 3940
# -----------------
#
# t # 5
# v 0 0
# v 1 0
# v 2 0
# v 3 3
# e 0 1 0
# e 1 2 0
# e 2 3 0
#
# Support: 4241
# -----------------
#
# t # 6
# v 0 0
# v 1 0
# v 2 3
# e 0 1 0
# e 1 2 0
#
# Support: 4264
# -----------------
#
# t # 7
# v 0 0
# v 1 3
# e 0 1 0
#
# Support: 4278
# -----------------
#
# Read:	0.3 s
# Mine:	4.4 s
# Total:	4.7 s

# %%
gspan_mine_rule(rule=25, with_neighbors=True, supp_ratio=0.9)
# Out:
# Number of graphs: 4486
# 100%|██████████| 4486/4486 [00:07<00:00, 600.94it/s]
# Skipped 222 graphs
# t # 0
# v 0 0
# v 1 0
# e 0 1 0
#
# Support: 4251
# -----------------
#
# t # 1
# v 0 0
# v 1 0
# v 2 0
# e 0 1 0
# e 1 2 0
#
# Support: 4231
# -----------------
#
# Read:	0.32 s
# Mine:	1.9200000000000002 s
# Total:	2.24 s
